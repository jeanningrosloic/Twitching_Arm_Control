# %%
from Network import *
time_step = 100.
net = Network(time_step)

# %%
inputs = np.random.uniform(0,1,size=(3,12))
print(inputs)
# Out:
# [[ 0.82105445  0.04451089  0.02588585  0.6865019   0.0065034   0.49438691
#    0.15192431  0.21014542  0.77257398  0.7644384   0.4723452   0.55816198]
#  [ 0.57090994  0.94731565  0.51387346  0.56550351  0.20304828  0.24201167
#    0.02474185  0.55461587  0.64890311  0.91168122  0.45832597  0.15908598]
#  [ 0.95117602  0.14873428  0.52670902  0.09581441  0.39290035  0.54290197
#    0.69534188  0.49464976  0.46028425  0.59188742  0.56339466  0.04978368]]

# %%
for rep in range(12):
    input_id = rep%3
    net.step(inputs[input_id])

net.figures()

# %%
len(net.motor_connections)

# %%
760*6

# %%
len(net.excitatory_neurons[0:20*6])

# %%
20*6

# %%
nest.Models()

# %%
nest.ConnectionRules()
